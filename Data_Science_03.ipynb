# %% [markdown]
# <a href="https://colab.research.google.com/github/siyab8160-max/Data-Science/blob/main/Data_Science_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Function to add two numbers

# %%
def add_( a,b):
  return a+b
a=int(input())
b=int (input())
print(add_(a,b))

# %% [markdown]
# LAMBDA FUNCTIONS The error in the lambda function is due to the return keyword. Lambda functions implicitly return the value of their expression, so return is not needed. I will fix it by removing the return keyword.

# %%
x = lambda a : 2*a
print(x(2))

# %% [markdown]
# FIZZ-BUZZ

# %%
class Solution:
    def fizzBuzz(self, n: int) -> List[str]:
        lst=[]
        for i in range (1,n+1):
            if i%3==0 and i%5==0:
                lst.append("FizzBuzz")
            elif i % 3 == 0:
                lst.append("Fizz")
            elif i % 5 == 0:
                lst.append("Buzz")
            else:
                lst.append(str(i))
        return lst

# %% [markdown]
# String fuctions

# %%
st=""
print(len(st))

# %%
st="siya bhardwaj"
st1=st.upper() # didn't modify the actual data, but returns a modified string
print(st1)
st2=st.lower()
print(st2)
st3=st.capitalize()
print(st3)
st4=st.title()
print(st4)
# Out:
# SIYA BHARDWAJ
# siya bhardwaj
# Siya bhardwaj
# Siya Bhardwaj

# %%
first_name=" siya    "
last_name="    bhardwaj   "
full_name=first_name+last_name
print(full_name)
#strip -> removes the spaces from the front and back of the string

st1=first_name.strip()
st2=last_name.strip()
full_name=st1+" "+st2
print(full_name)

#lstrip -> removes from the left of the string
#rstrip -> removes from the right of the string
# Out:
#  siya        bhardwaj
# siya bhardwaj

# %%
a=" today  "
b="    weather   "
c=" is GooD   "
a=a.strip()
b=b.strip()
c=c.lower()
c=c.strip()
sentence = a+", "+b+" "+c+"."
sentence=sentence.capitalize()
print(sentence)

sentence=sentence.replace("good","bad")
print(sentence)
index=sentence.find("bad")
print(index)
index=sentence.find("good")
print(index) # cannot find so returns -1

#index=sentence.index("good") -> gives value error : substring not found
index=sentence.index("bad")
print(index)

s=sentence.startswith("Today")
print(s) # case sensitive

s=sentence.endswith("bad.")
print(s)
# Out:
# Today, weather is good.
# Today, weather is bad.
# 18
# -1
# 18
# True
# True

# %% [markdown]
# Valid Palindrome

# %%
#s=s.lower()
#new_st=""
#for i in s: # string is an iterable in python
  #if(i>='a' and i<='z' ) or (i>='9' and i<='9'):

# %% [markdown]
# SLICING
#
# SET
#
# DICTIONARY

# %%
dct={
    "name":["siya","jiya","akshita","aman","tejas"],
    "age":21,
    "class":"alpha"
}
print(dct["name"][0])
dct['id']=1
print(dct)

del dct["name"]
print(dct)
# Out:
# siya
# {'name': ['siya', 'jiya', 'akshita', 'aman', 'tejas'], 'age': 21, 'class': 'alpha', 'id': 1}
# {'age': 21, 'class': 'alpha', 'id': 1}
